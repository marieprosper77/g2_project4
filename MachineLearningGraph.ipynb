# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd   
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
import itertools

import psycopg2
from sqlalchemy import create_engine

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier


# from xgboost import XGBClassifier
# from lightgbm import LGBMClassifier
# from catboost import CatBoostClassifier
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier

# %%
###Process
###Use Logistics Regression and Random Forest to compare the results
###Preprocess: Feature Selection (Reference below),Dummify, Standardize,
    ###Random Forest feature selection, do this after the Random Forest
###Use Random Forest feature selection to see if it improves the results
###For the models that we use; fit and accuracy
###Pick the model with the best accuracy, save the model using job lids
###Hard code the results or the model (results will change)
###Save output/input as a JSON file or use Flask get/post methods(very easy)
###Create a flask app
###Load the model into the app

# %%
# Create an engine instance
alchemyEngine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/Project4')
#create_engine(f'postgresql://{username}:{password}@localhost:5432/employees')

# Connect to PostgreSQL server
dbConnection = alchemyEngine.connect();

# %%
#Credit Record Data Frame
# Read data from PostgreSQL database table and load into a DataFrame instance

Credit_Record_df = pd.read_sql("select * from \"credit_record2\"", dbConnection);

#pd.set_option('display.expand_frame_repr', False);

# %%
# Read data from PostgreSQL database table and load into a DataFrame instance

Application_Record_df = pd.read_sql("select * from \"application_record\"", dbConnection);

#pd.set_option('display.expand_frame_repr', False);

# Close the database connection

dbConnection.close();

# %%
Credit_Record_df
# Out:
#               id  months_balance status
# 0        5001711             0.0      X
# 1        5001711            -1.0      0
# 2        5001711            -2.0      0
# 3        5001711            -3.0      0
# 4        5001712             0.0      C
# ...          ...             ...    ...
# 1048570  5150487           -25.0      C
# 1048571  5150487           -26.0      C
# 1048572  5150487           -27.0      C
# 1048573  5150487           -28.0      C
# 1048574  5150487           -29.0      C
#
# [1048575 rows x 3 columns]

# %%
Application_Record_df
# Out:
#              id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438505  6840104           M            N               Y             0
# 438506  6840222           F            N               N             0
# 438507  6841878           F            N               N             0
# 438508  6842765           F            N               Y             0
# 438509  6842885           F            N               Y             0
#
#         amt_income_total      name_income_type            name_education_type  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438505          135000.0             Pensioner  Secondary / secondary special
# 438506          103500.0               Working  Secondary / secondary special
# 438507           54000.0  Commercial associate               Higher education
# 438508           72000.0             Pensioner  Secondary / secondary special
# 438509          121500.0               Working  Secondary / secondary special
#
#           name_family_status  name_housing_type  days_birth  days_employed  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438505             Separated  House / apartment      -22717         365243
# 438506  Single / not married  House / apartment      -15939          -3007
# 438507  Single / not married       With parents       -8169           -372
# 438508               Married  House / apartment      -21673         365243
# 438509               Married  House / apartment      -18858          -1201
#
#         flag_mobil  flag_work_phone  flag_phone  flag_email occupation_type  \
# 0                1                1           0           0            None
# 1                1                1           0           0            None
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438505           1                0           0           0            None
# 438506           1                0           0           0        Laborers
# 438507           1                1           0           0     Sales staff
# 438508           1                0           0           0            None
# 438509           1                0           1           0     Sales staff
#
#         cnt_fam_members
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438505              1.0
# 438506              1.0
# 438507              1.0
# 438508              2.0
# 438509              2.0
#
# [438510 rows x 18 columns]

# %%
###Merge the Datasets
new_df = pd.merge(Application_Record_df,Credit_Record_df)
new_df
# Out:
#              id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         amt_income_total name_income_type            name_education_type  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           name_family_status name_housing_type  days_birth  days_employed  \
# 0             Civil marriage  Rented apartment      -12005          -4542
# 1             Civil marriage  Rented apartment      -12005          -4542
# 2             Civil marriage  Rented apartment      -12005          -4542
# 3             Civil marriage  Rented apartment      -12005          -4542
# 4             Civil marriage  Rented apartment      -12005          -4542
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment       -9188          -1193
# 777711  Single / not married  Rented apartment       -9188          -1193
# 777712  Single / not married  Rented apartment       -9188          -1193
# 777713  Single / not married  Rented apartment       -9188          -1193
# 777714  Single / not married  Rented apartment       -9188          -1193
#
#         flag_mobil  flag_work_phone  flag_phone  flag_email occupation_type  \
# 0                1                1           0           0            None
# 1                1                1           0           0            None
# 2                1                1           0           0            None
# 3                1                1           0           0            None
# 4                1                1           0           0            None
# ...            ...              ...         ...         ...             ...
# 777710           1                0           0           0        Laborers
# 777711           1                0           0           0        Laborers
# 777712           1                0           0           0        Laborers
# 777713           1                0           0           0        Laborers
# 777714           1                0           0           0        Laborers
#
#         cnt_fam_members  months_balance status
# 0                   2.0             0.0      C
# 1                   2.0            -1.0      C
# 2                   2.0            -2.0      C
# 3                   2.0            -3.0      C
# 4                   2.0            -4.0      C
# ...                 ...             ...    ...
# 777710              1.0            -9.0      0
# 777711              1.0           -10.0      2
# 777712              1.0           -11.0      1
# 777713              1.0           -12.0      0
# 777714              1.0           -13.0      0
#
# [777715 rows x 20 columns]

# %%
graph_df = pd.merge(Application_Record_df,Credit_Record_df)
graph_df.head()
# Out:
#         id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0  5008804           M            Y               Y             0
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
#
#    amt_income_total name_income_type name_education_type name_family_status  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
#
#   name_housing_type  days_birth  days_employed  flag_mobil  flag_work_phone  \
# 0  Rented apartment      -12005          -4542           1                1
# 1  Rented apartment      -12005          -4542           1                1
# 2  Rented apartment      -12005          -4542           1                1
# 3  Rented apartment      -12005          -4542           1                1
# 4  Rented apartment      -12005          -4542           1                1
#
#    flag_phone  flag_email occupation_type  cnt_fam_members  months_balance  \
# 0           0           0            None              2.0             0.0
# 1           0           0            None              2.0            -1.0
# 2           0           0            None              2.0            -2.0
# 3           0           0            None              2.0            -3.0
# 4           0           0            None              2.0            -4.0
#
#   status
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C

# %%
graph_df["Credit Risk"] = graph_df["status"].apply(lambda x: "low_risk" if(x == "C" or x == "X") else "high_risk")
new_df.head(20)
# Out:
#          id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0   5008804           M            Y               Y             0
# 1   5008804           M            Y               Y             0
# 2   5008804           M            Y               Y             0
# 3   5008804           M            Y               Y             0
# 4   5008804           M            Y               Y             0
# 5   5008804           M            Y               Y             0
# 6   5008804           M            Y               Y             0
# 7   5008804           M            Y               Y             0
# 8   5008804           M            Y               Y             0
# 9   5008804           M            Y               Y             0
# 10  5008804           M            Y               Y             0
# 11  5008804           M            Y               Y             0
# 12  5008804           M            Y               Y             0
# 13  5008804           M            Y               Y             0
# 14  5008804           M            Y               Y             0
# 15  5008804           M            Y               Y             0
# 16  5008805           M            Y               Y             0
# 17  5008805           M            Y               Y             0
# 18  5008805           M            Y               Y             0
# 19  5008805           M            Y               Y             0
#
#     amt_income_total name_income_type name_education_type name_family_status  \
# 0           427500.0          Working    Higher education     Civil marriage
# 1           427500.0          Working    Higher education     Civil marriage
# 2           427500.0          Working    Higher education     Civil marriage
# 3           427500.0          Working    Higher education     Civil marriage
# 4           427500.0          Working    Higher education     Civil marriage
# 5           427500.0          Working    Higher education     Civil marriage
# 6           427500.0          Working    Higher education     Civil marriage
# 7           427500.0          Working    Higher education     Civil marriage
# 8           427500.0          Working    Higher education     Civil marriage
# 9           427500.0          Working    Higher education     Civil marriage
# 10          427500.0          Working    Higher education     Civil marriage
# 11          427500.0          Working    Higher education     Civil marriage
# 12          427500.0          Working    Higher education     Civil marriage
# 13          427500.0          Working    Higher education     Civil marriage
# 14          427500.0          Working    Higher education     Civil marriage
# 15          427500.0          Working    Higher education     Civil marriage
# 16          427500.0          Working    Higher education     Civil marriage
# 17          427500.0          Working    Higher education     Civil marriage
# 18          427500.0          Working    Higher education     Civil marriage
# 19          427500.0          Working    Higher education     Civil marriage
#
#    name_housing_type  days_birth  days_employed  flag_mobil  flag_work_phone  \
# 0   Rented apartment      -12005          -4542           1                1
# 1   Rented apartment      -12005          -4542           1                1
# 2   Rented apartment      -12005          -4542           1                1
# 3   Rented apartment      -12005          -4542           1                1
# 4   Rented apartment      -12005          -4542           1                1
# 5   Rented apartment      -12005          -4542           1                1
# 6   Rented apartment      -12005          -4542           1                1
# 7   Rented apartment      -12005          -4542           1                1
# 8   Rented apartment      -12005          -4542           1                1
# 9   Rented apartment      -12005          -4542           1                1
# 10  Rented apartment      -12005          -4542           1                1
# 11  Rented apartment      -12005          -4542           1                1
# 12  Rented apartment      -12005          -4542           1                1
# 13  Rented apartment      -12005          -4542           1                1
# 14  Rented apartment      -12005          -4542           1                1
# 15  Rented apartment      -12005          -4542           1                1
# 16  Rented apartment      -12005          -4542           1                1
# 17  Rented apartment      -12005          -4542           1                1
# 18  Rented apartment      -12005          -4542           1                1
# 19  Rented apartment      -12005          -4542           1                1
#
#     flag_phone  flag_email occupation_type  cnt_fam_members  months_balance  \
# 0            0           0            None              2.0             0.0
# 1            0           0            None              2.0            -1.0
# 2            0           0            None              2.0            -2.0
# 3            0           0            None              2.0            -3.0
# 4            0           0            None              2.0            -4.0
# 5            0           0            None              2.0            -5.0
# 6            0           0            None              2.0            -6.0
# 7            0           0            None              2.0            -7.0
# 8            0           0            None              2.0            -8.0
# 9            0           0            None              2.0            -9.0
# 10           0           0            None              2.0           -10.0
# 11           0           0            None              2.0           -11.0
# 12           0           0            None              2.0           -12.0
# 13           0           0            None              2.0           -13.0
# 14           0           0            None              2.0           -14.0
# 15           0           0            None              2.0           -15.0
# 16           0           0            None              2.0             0.0
# 17           0           0            None              2.0            -1.0
# 18           0           0            None              2.0            -2.0
# 19           0           0            None              2.0            -3.0
#
#    status
# 0       C
# 1       C
# 2       C
# 3       C
# 4       C
# 5       C
# 6       C
# 7       C
# 8       C
# 9       C
# 10      C
# 11      C
# 12      C
# 13      1
# 14      0
# 15      X
# 16      C
# 17      C
# 18      C
# 19      C

# %%
###Merge the Datasets
new_df.dtypes
# Out:
# id                      object
# code_gender             object
# flag_own_car            object
# flag_own_realty         object
# cnt_children             int64
# amt_income_total       float64
# name_income_type        object
# name_education_type     object
# name_family_status      object
# name_housing_type       object
# days_birth               int64
# days_employed            int64
# flag_mobil               int64
# flag_work_phone          int64
# flag_phone               int64
# flag_email               int64
# occupation_type         object
# cnt_fam_members        float64
# months_balance         float64
# status                  object
# dtype: object

# %%
#credit_risk_df = pd.DataFrame()
new_df["Credit Risk"] = new_df["status"].apply(lambda x: "low_risk" if(x == "C" or x == "X") else "high_risk")
new_df.head(20)
# Out:
#          id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0   5008804           M            Y               Y             0
# 1   5008804           M            Y               Y             0
# 2   5008804           M            Y               Y             0
# 3   5008804           M            Y               Y             0
# 4   5008804           M            Y               Y             0
# 5   5008804           M            Y               Y             0
# 6   5008804           M            Y               Y             0
# 7   5008804           M            Y               Y             0
# 8   5008804           M            Y               Y             0
# 9   5008804           M            Y               Y             0
# 10  5008804           M            Y               Y             0
# 11  5008804           M            Y               Y             0
# 12  5008804           M            Y               Y             0
# 13  5008804           M            Y               Y             0
# 14  5008804           M            Y               Y             0
# 15  5008804           M            Y               Y             0
# 16  5008805           M            Y               Y             0
# 17  5008805           M            Y               Y             0
# 18  5008805           M            Y               Y             0
# 19  5008805           M            Y               Y             0
#
#     amt_income_total name_income_type name_education_type name_family_status  \
# 0           427500.0          Working    Higher education     Civil marriage
# 1           427500.0          Working    Higher education     Civil marriage
# 2           427500.0          Working    Higher education     Civil marriage
# 3           427500.0          Working    Higher education     Civil marriage
# 4           427500.0          Working    Higher education     Civil marriage
# 5           427500.0          Working    Higher education     Civil marriage
# 6           427500.0          Working    Higher education     Civil marriage
# 7           427500.0          Working    Higher education     Civil marriage
# 8           427500.0          Working    Higher education     Civil marriage
# 9           427500.0          Working    Higher education     Civil marriage
# 10          427500.0          Working    Higher education     Civil marriage
# 11          427500.0          Working    Higher education     Civil marriage
# 12          427500.0          Working    Higher education     Civil marriage
# 13          427500.0          Working    Higher education     Civil marriage
# 14          427500.0          Working    Higher education     Civil marriage
# 15          427500.0          Working    Higher education     Civil marriage
# 16          427500.0          Working    Higher education     Civil marriage
# 17          427500.0          Working    Higher education     Civil marriage
# 18          427500.0          Working    Higher education     Civil marriage
# 19          427500.0          Working    Higher education     Civil marriage
#
#    name_housing_type  ...  days_employed  flag_mobil  flag_work_phone  \
# 0   Rented apartment  ...          -4542           1                1
# 1   Rented apartment  ...          -4542           1                1
# 2   Rented apartment  ...          -4542           1                1
# 3   Rented apartment  ...          -4542           1                1
# 4   Rented apartment  ...          -4542           1                1
# 5   Rented apartment  ...          -4542           1                1
# 6   Rented apartment  ...          -4542           1                1
# 7   Rented apartment  ...          -4542           1                1
# 8   Rented apartment  ...          -4542           1                1
# 9   Rented apartment  ...          -4542           1                1
# 10  Rented apartment  ...          -4542           1                1
# 11  Rented apartment  ...          -4542           1                1
# 12  Rented apartment  ...          -4542           1                1
# 13  Rented apartment  ...          -4542           1                1
# 14  Rented apartment  ...          -4542           1                1
# 15  Rented apartment  ...          -4542           1                1
# 16  Rented apartment  ...          -4542           1                1
# 17  Rented apartment  ...          -4542           1                1
# 18  Rented apartment  ...          -4542           1                1
# 19  Rented apartment  ...          -4542           1                1
#
#     flag_phone  flag_email  occupation_type cnt_fam_members  months_balance  \
# 0            0           0             None             2.0             0.0
# 1            0           0             None             2.0            -1.0
# 2            0           0             None             2.0            -2.0
# 3            0           0             None             2.0            -3.0
# 4            0           0             None             2.0            -4.0
# 5            0           0             None             2.0            -5.0
# 6            0           0             None             2.0            -6.0
# 7            0           0             None             2.0            -7.0
# 8            0           0             None             2.0            -8.0
# 9            0           0             None             2.0            -9.0
# 10           0           0             None             2.0           -10.0
# 11           0           0             None             2.0           -11.0
# 12           0           0             None             2.0           -12.0
# 13           0           0             None             2.0           -13.0
# 14           0           0             None             2.0           -14.0
# 15           0           0             None             2.0           -15.0
# 16           0           0             None             2.0             0.0
# 17           0           0             None             2.0            -1.0
# 18           0           0             None             2.0            -2.0
# 19           0           0             None             2.0            -3.0
#
#     status Credit Risk
# 0        C    low_risk
# 1        C    low_risk
# 2        C    low_risk
# 3        C    low_risk
# 4        C    low_risk
# 5        C    low_risk
# 6        C    low_risk
# 7        C    low_risk
# 8        C    low_risk
# 9        C    low_risk
# 10       C    low_risk
# 11       C    low_risk
# 12       C    low_risk
# 13       1   high_risk
# 14       0   high_risk
# 15       X    low_risk
# 16       C    low_risk
# 17       C    low_risk
# 18       C    low_risk
# 19       C    low_risk
#
# [20 rows x 21 columns]

# %%
list(new_df.columns)
# Out:
# ['id',
#  'code_gender',
#  'flag_own_car',
#  'flag_own_realty',
#  'cnt_children',
#  'amt_income_total',
#  'name_income_type',
#  'name_education_type',
#  'name_family_status',
#  'name_housing_type',
#  'days_birth',
#  'days_employed',
#  'flag_mobil',
#  'flag_work_phone',
#  'flag_phone',
#  'flag_email',
#  'occupation_type',
#  'cnt_fam_members',
#  'months_balance',
#  'status',
#  'Credit Risk']

# %%
# Comment out what you do not want to keep
training_columns = [
#     'id',
 'code_gender',
 'flag_own_car',
 'flag_own_realty',
 'cnt_children',
 'amt_income_total',
#  'name_income_type',
#  'name_education_type',
#  'name_family_status',
#  'name_housing_type',
#  'days_birth',
#  'days_employed',
#  'flag_mobil',
#  'flag_work_phone',
#  'flag_phone',
#  'flag_email',
#  'occupation_type',
 'cnt_fam_members',
#  'months_balance',
#  'status',
 'Credit Risk'
]

# Select the target feature
target_feature = 'Credit Risk'
# In case the target feature gets left inside the training columns
if (target_feature in training_columns):
    training_columns.remove(target_feature)

# %%
# split the data
X  = pd.get_dummies(new_df[training_columns])
y = new_df[[target_feature]].values.ravel()
print(X.shape, y.shape)
# Out:
# (777715, 9) (777715,)

# %%
X
# Out:
#         cnt_children  amt_income_total  cnt_fam_members  code_gender_F  \
# 0                  0          427500.0              2.0              0
# 1                  0          427500.0              2.0              0
# 2                  0          427500.0              2.0              0
# 3                  0          427500.0              2.0              0
# 4                  0          427500.0              2.0              0
# ...              ...               ...              ...            ...
# 777710             0          112500.0              1.0              0
# 777711             0          112500.0              1.0              0
# 777712             0          112500.0              1.0              0
# 777713             0          112500.0              1.0              0
# 777714             0          112500.0              1.0              0
#
#         code_gender_M  flag_own_car_N  flag_own_car_Y  flag_own_realty_N  \
# 0                   1               0               1                  0
# 1                   1               0               1                  0
# 2                   1               0               1                  0
# 3                   1               0               1                  0
# 4                   1               0               1                  0
# ...               ...             ...             ...                ...
# 777710              1               1               0                  0
# 777711              1               1               0                  0
# 777712              1               1               0                  0
# 777713              1               1               0                  0
# 777714              1               1               0                  0
#
#         flag_own_realty_Y
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 777710                  1
# 777711                  1
# 777712                  1
# 777713                  1
# 777714                  1
#
# [777715 rows x 9 columns]

# %%
### Graphs Section
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# graph_df_convert = income_graph_df[['amt_income_total','cnt_children']].astype(int)

# %%
graph_df[graph_df["cnt_children"].isin([14])]
# Out:
#              id code_gender flag_own_car flag_own_realty  cnt_children  \
# 306620  5061207           M            Y               Y            14
# 306621  5061207           M            Y               Y            14
# 306622  5061207           M            Y               Y            14
# 306623  5061207           M            Y               Y            14
# 306624  5061207           M            Y               Y            14
# ...         ...         ...          ...             ...           ...
# 306726  5061211           M            Y               Y            14
# 306727  5061211           M            Y               Y            14
# 306728  5061211           M            Y               Y            14
# 306729  5061211           M            Y               Y            14
# 306730  5061211           M            Y               Y            14
#
#         amt_income_total name_income_type            name_education_type  \
# 306620          225000.0          Working  Secondary / secondary special
# 306621          225000.0          Working  Secondary / secondary special
# 306622          225000.0          Working  Secondary / secondary special
# 306623          225000.0          Working  Secondary / secondary special
# 306624          225000.0          Working  Secondary / secondary special
# ...                  ...              ...                            ...
# 306726          225000.0          Working  Secondary / secondary special
# 306727          225000.0          Working  Secondary / secondary special
# 306728          225000.0          Working  Secondary / secondary special
# 306729          225000.0          Working  Secondary / secondary special
# 306730          225000.0          Working  Secondary / secondary special
#
#        name_family_status  name_housing_type  ...  days_employed  flag_mobil  \
# 306620          Separated  House / apartment  ...          -1689           1
# 306621          Separated  House / apartment  ...          -1689           1
# 306622          Separated  House / apartment  ...          -1689           1
# 306623          Separated  House / apartment  ...          -1689           1
# 306624          Separated  House / apartment  ...          -1689           1
# ...                   ...                ...  ...            ...         ...
# 306726          Separated  House / apartment  ...          -1689           1
# 306727          Separated  House / apartment  ...          -1689           1
# 306728          Separated  House / apartment  ...          -1689           1
# 306729          Separated  House / apartment  ...          -1689           1
# 306730          Separated  House / apartment  ...          -1689           1
#
#         flag_work_phone  flag_phone  flag_email  occupation_type  \
# 306620                0           0           0          Drivers
# 306621                0           0           0          Drivers
# 306622                0           0           0          Drivers
# 306623                0           0           0          Drivers
# 306624                0           0           0          Drivers
# ...                 ...         ...         ...              ...
# 306726                0           0           0          Drivers
# 306727                0           0           0          Drivers
# 306728                0           0           0          Drivers
# 306729                0           0           0          Drivers
# 306730                0           0           0          Drivers
#
#        cnt_fam_members  months_balance  status Credit Risk
# 306620            15.0             0.0       0   high_risk
# 306621            15.0            -1.0       0   high_risk
# 306622            15.0            -2.0       0   high_risk
# 306623            15.0            -3.0       0   high_risk
# 306624            15.0            -4.0       0   high_risk
# ...                ...             ...     ...         ...
# 306726            15.0           -39.0       0   high_risk
# 306727            15.0           -40.0       0   high_risk
# 306728            15.0           -41.0       0   high_risk
# 306729            15.0           -42.0       0   high_risk
# 306730            15.0           -43.0       0   high_risk
#
# [111 rows x 21 columns]

# %%
child_count_graph_df = graph_df[['cnt_children','id']]
child_count_graph_df.head(10)
# Out:
#    cnt_children       id
# 0             0  5008804
# 1             0  5008804
# 2             0  5008804
# 3             0  5008804
# 4             0  5008804
# 5             0  5008804
# 6             0  5008804
# 7             0  5008804
# 8             0  5008804
# 9             0  5008804

# %%
df = child_count_graph_df.drop_duplicates(subset=['id'])
df.head()
# Out:
#     cnt_children       id
# 0              0  5008804
# 16             0  5008805
# 31             0  5008806
# 61             0  5008808
# 66             0  5008809

# %%
groupby_df = df.groupby(by='cnt_children').count()
groupby_df
# Out:
#                  id
# cnt_children
# 0             25201
# 1              7492
# 2              3256
# 3               419
# 4                63
# 5                20
# 7                 2
# 14                3
# 19                1

# %%
#plot = groupby_df.plot.pie(y='id', figsize=(10, 10))

# %%
groupby_df.plot.bar(y='id', rot=0)
# Out:
# <AxesSubplot:xlabel='cnt_children'>

# %%
income_graph_df = graph_df[['amt_income_total','id']].drop_duplicates(subset=['id'])
income_graph_df.head()
# Out:
#     amt_income_total       id
# 0           427500.0  5008804
# 16          427500.0  5008805
# 31          112500.0  5008806
# 61          270000.0  5008808
# 66          270000.0  5008809

# %%
income_group_by = income_graph_df.groupby(by='amt_income_total').count().reset_index()
income_group_by
# Out:
#      amt_income_total  id
# 0             27000.0   3
# 1             29250.0   7
# 2             30150.0   3
# 3             31500.0  16
# 4             31531.5   3
# ..                ...  ..
# 260          945000.0   4
# 261          990000.0   4
# 262         1125000.0   3
# 263         1350000.0   6
# 264         1575000.0   8
#
# [265 rows x 2 columns]

# %%
###Work through creating ranges for salary

income_group_by.plot.bar(y='id', rot=0)
# Out:
# <AxesSubplot:>

# %%
gender_graph_df = graph_df[['code_gender','id']].drop_duplicates(subset=['id'])
gender_graph_df.head()
# Out:
#    code_gender       id
# 0            M  5008804
# 16           M  5008805
# 31           M  5008806
# 61           F  5008808
# 66           F  5008809

# %%
gender_graph_df_groupby = gender_graph_df.groupby(by='code_gender').count()
gender_graph_df_groupby
# Out:
#                 id
# code_gender
# F            24430
# M            12027

# %%
#gender_graph_df_groupby['code_gender'].astype(int)

# %%
gender_graph_df_groupby.dtypes
# Out:
# id    int64
# dtype: object

# %%
plt.pie(gender_graph_df_groupby["id"], labels = gender_graph_df_groupby["id"])
plt.show()

# %%
# make the plot
gender_graph_df_groupby.plot(kind='pie', subplots=True, figsize=(8, 8))

# show the plot
plt.show()

# %%
# sns.set(font_scale=1.4)
# income_group_by.set_index('amt_income_total')['id'].plot(figsize=(12, 10), linewidth=2.5, color='maroon')
# plt.xlabel("Date", labelpad=15)
# plt.ylabel("Daily Step Count", labelpad=15)
# plt.title("My Daily Step Count Tracked by Fitbit", y=1.02, fontsize=22);

# %%
### Random Forest

# %%
# X_train, X_test, y_train, y_test = train_test_split(X,y, 
#                                                     stratify=y, test_size=0.3,
#                                                     random_state = 100)

# %%
# model = RandomForestClassifier(n_estimators=250,
#                               max_depth=12,
#                               min_samples_leaf=16
#                               )
# model.fit(X_train, y_train)
# y_predict = model.predict(X_test)

# print('Accuracy Score is {:.5}'.format(accuracy_score(y_test, y_predict)))
# print(pd.DataFrame(confusion_matrix(y_test,y_predict)))

# # plot_confusion_matrix(confusion_matrix(y_test,y_predict),
# #                       classes=class_names, normalize = True, 
# #                       title='Normalized Confusion Matrix: Ramdom Forests')

# %%
#### Logistics Regression
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
# logisticRegr = LogisticRegression(
#     solver='lbfgs', 
#     max_iter=100,
#     random_state=0
# )
# logisticRegr.fit(X_train, y_train)
# print("LogisticRegression score: ", logisticRegr.score(X_test, y_test))

# %%
###Do a comparison using a RO seaker
###Create graphs for both models for presentation purposes
###Figure out how to create ranges with the upload

# %%
#Save the model
#model.save("CreditRiskModel.h5")
